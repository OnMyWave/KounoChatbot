# %%
import pandas as pd

data = pd.read_csv('arduino_naver_qa.csv')

# %%
data.head()
# Out:
#    Unnamed: 0          qt_title  \
# 0           0   팅커캐드 아두이노 브레드보드
# 1           1  서보모터 크롤링 오류가 뭔가요
# 2           2     아두이노 레오나르도 긴급
# 3           3       아두이노 코딩 랜덤값
# 4           4     아두이노 산소 농도 센서
#
#                                           qt_content  \
# 0  안녕하세요 아두이노 입문자입니다.\n팅커캐드로 아두이노 튜토리얼을 진행하는 중에 궁...
# 1  서보모터 사용 시 발생할 수 있는 오류 중에 크롤링 오류라는 게 있더라구요... 설...
# 2  이거 왜 오류나나요ㅠㅠ\n\n코드\n#include <Keyboard.h>\n#in...
# 3  아두이노 코딩 랜덤값에대한 질문입니다\n\nRandomseed(AnaologA0) ...
# 4  안녕하세요. 탐구를 진행중인 고등학생입니다.\n제가 컴공과 지망이라서\n아두이노를 ...
#
#                                          ans_content
# 0  아래위로 연결 해주는건 전원 라인을 위해 연결 하는데...현재의 회로에서는 위쪽 라...
# 1                                             헉 뭐죠..
# 2  반갑습니다.#include <Keyboard.h>#include <KeyboardL...
# 3  매번 킬 때마다 동일한 랜덤값이 나오므로randomSeed(analogRead(0)...
# 4  반갑습니다.s+4ox 센서는 Anode 와 Cathode간의 전압차로 산소의 질을 ...

# %%
data.drop_duplicates(['qt_content'], keep='first')
# Out:
#      Unnamed: 0          qt_title  \
# 0             0   팅커캐드 아두이노 브레드보드
# 1             1  서보모터 크롤링 오류가 뭔가요
# 2             2     아두이노 레오나르도 긴급
# 3             3       아두이노 코딩 랜덤값
# 4             4     아두이노 산소 농도 센서
# ..          ...               ...
# 992         992        아두이노 거리센서?
# 995         995       아두이노 키보드 제작
# 996         996         아두이노 네오픽셀
# 998         998       아두이노 적외선 센서
# 999         999     아두이노 부품 구하는 곳
#
#                                             qt_content  \
# 0    안녕하세요 아두이노 입문자입니다.\n팅커캐드로 아두이노 튜토리얼을 진행하는 중에 궁...
# 1    서보모터 사용 시 발생할 수 있는 오류 중에 크롤링 오류라는 게 있더라구요... 설...
# 2    이거 왜 오류나나요ㅠㅠ\n\n코드\n#include <Keyboard.h>\n#in...
# 3    아두이노 코딩 랜덤값에대한 질문입니다\n\nRandomseed(AnaologA0) ...
# 4    안녕하세요. 탐구를 진행중인 고등학생입니다.\n제가 컴공과 지망이라서\n아두이노를 ...
# ..                                                 ...
# 992  20m까지도 볼 수 있는 그런 센서가 있나요??\n아두이노 호환가능한걸로..\n\n...
# 995  안녕하세요 이번에 키보드를 한 번 제작해보려고 해서 자료를 조금 찾아봤는데 이해가 ...
# ...

# %%
data.to_csv('arduino_naver_qa.csv', encoding='utf-8-sig')
